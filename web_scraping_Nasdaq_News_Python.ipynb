# %% [markdown]
# ## Web Scraping Nasdaq News Using Python

# %% [markdown]
# ### Introduction

# %% [markdown]
# The Nasdaq (National Association of Securities Dealers Automated Quotations) Stock Market is an electronic stock exchange in the United States. It is the second largest stock exchange in the world by market capitalization.
#
# The Nasdaq Stock Market website provides stock market news, business news, and financial news useful for data analysis on stocks and trading.
#
# Web scraping or extract information from Nasdaq news website allows us to perform stock price prediction, stock market sentiment analysis, and equity research, etc.

# %% [markdown]
# ### Project goal

# %% [markdown]
# To scrap most active Nasdaq stocks from Nasdaq news website

# %% [markdown]
# ### Data

# %% [markdown]
# Source: https://www.nasdaq.com/news/

# %%
#import libraries
import urllib.request

#import the Beautiful soup function to parse the data returned from the website
from bs4 import BeautifulSoup

# %%
# Specify the url
nasdaq = "https://www.nasdaq.com/markets/most-active.aspx"

# %%
# Open the connection and download html page from url
webpage = urllib.request.urlopen(nasdaq)

# %%
#Parse the html data in the 'webpage' variable and save as Beautiful Soup format
soup = BeautifulSoup(webpage)

# %%
# Check nested structure of the html page
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="nasdaqCom inner no-js" lang="en-us" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="https://ogp.me/ns#">
#  <head>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K2BQVP7');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script>
#    (function(){
#     var is_chrome;
#     if(typeof navigator.vendor!="undefined")
# 	    is_chrome = ((navigator.userAgent.toLowerCase().indexOf('chrome') > -1) && (navigator.vendor.toLowerCase().indexOf("google") > -1));
#     else
# 	    is_chrome = false;
# })();
#   </script>
#   <!-- includes\2-column.master -->
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge;chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width" name="viewport"/>
#   <!-- START page level head content -->
#   <title>
#    Most Active Stocks - Most Active Share Volume
#   </title>
#   <!--markets/most-active.aspx-->
#   <meta content="most active,most active stocks,most active etfs,most declined etfs,most active share volume,most active volume" name="keywords"/>
#   <meta content="Most Active Stocks - Includes Most Active Share Volume, Most Advanced, Most Declined, and Most Active by Dollar Volume for NASDAQ, NYSE, and AMEX stocks." name="description"/>
#   <link href="https://www.nasdaq.com/markets/most-active.aspx" rel="canonical"/>
#   <link href="https://m.nasdaq.com/quotes/most-active-mobile.aspx" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <meta content="NASDAQ Most Active Stocks - NASDAQ.com" property="og:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="NASDAQ.com" property="og:site_name"/>
#   <meta content="https://www.nasdaq.com/markets/most-active.aspx" property="og:url"/>
#   <meta content="/images/Q-logo.jpg" property="og:image"/>
#   <script type="text/javascript">
#    var myPage = 'intradaymostactive';
# var sectionId = 'liActivity'; //section tab
# var breadCrumbId = 'maMA'; //page
# var is_dartSite = "mktsnews";
# var is_dartZone = "mostactive";
# var propVar = "Most Active Share Volume";
# var propVar15 = "Market Activity";
#
# /*
# SRA ad definitions, this should always correspond with the ad calls on the page
# if an ad is removed from the page, it should be removed from here as well
# */
#
# var useSRA = true;
# var premakeAds = [];
#
# premakeAds.push({ 'label': 'ad', 'size': '160x600', 'site': is_dartSite, 'zone': is_dartZone });
#   </script>
#   <!-- END page level head content -->
#   <!--********************************* BEGIN includes/global-references.inc **************************-->
#   <!-- global stylesheets -->
#   <link href="https://www.nasdaq.com/includes/global.min-04172019v1.css" rel="stylesheet" type="text/css"/>
#   <!--[if lt IE 9]>
# <script src="https://www.nasdaq.com/includes/html5shiv-printshiv.js"></script>
# <link rel="stylesheet" type="text/css" href="https://www.nasdaq.com/includes/global-ie8.min-11212015v1.css"/>
# <![endif]-->
#   <!-- favicon and shortcut icons -->
#   <link href="https://www.nasdaq.com/images/Q_apple.png" rel="apple-touch-icon"/>
#   <link href="https://www.nasdaq.com/images/qfav.ico" rel="shortcut icon" type="image/ico"/>
#   <link href="https://www.nasdaq.com/images/qfav.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://www.nasdaq.com/images/qfav.ico" rel="shortcut icon" type="image/x-icon"/>
#   <!-- scripts -->
#   <!-- Casale -->
#   <script async="" src="https://js-sec.indexww.com/ht/headertag-nasdaq.js">
#   </script>
#   <!-- GPT -->
#   <script async="true" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#   </script>
#   <script src="https://www.nasdaq.com/dynamic_includes/marketstatus.js">
#   </script>
#   <script src="https://www.nasdaq.com/aspx/marketstatus.aspx">
#   </script>
#   <script src="https://www.nasdaq.com/includes/jquery.min.js">
#   </script>
#   <script src="https://www.nasdaq.com/includes/global.min-08132019v1.js?1">
#   </script>
#   <script src="https://www.nasdaq.com/includes/cookie_policy.js?05232018v1">
#   </script>
#   <!-- NASDAQ nasdaq.com DurationMedia -->
#   <script src="https://pr.realvu.net/flip/2/c=E420_f=site_si=952" type="text/javascript">
#   </script>
#   <!-- the dynamic css container -->
#   <style title="dynamic" type="text/css">
#   </style>
#   <script type="text/javascript">
#    //<![CDATA[
# updateSiteTheme();
# //]]>
#       //var btfRefresh = [];
#
#       //function adBtfRefresh(premakeAds) {
#       //  if ((premakeAds.label == "ad") && (premakeAds.site == "btf")) {
#       //    btfRefresh.push(premakeads);
#       //  }
#       //}
#
#       //googletag.cmd.push(function () {
#       //autoAdRefresh(btfRefresh, 60000);
#       //});
#
#       googletag.cmd.push(function () {
# 	  autoAdRefresh([0,1,2,3,4], 35000);
# 	  });
#   </script>
#   <!-- <script type='text/javascript' src='//rndntpmgnj-a.akamaihd.net/NA2L50A6M.js' async=''></script>-->
#   <!--  Quantcast Tag -->
#   <script>
#    var ezt = ezt ||[];
#
#       (function(){
#       var elem = document.createElement('script');
#       elem.src = (document.location.protocol == "https:" ? "https://secure" : "https://pixel") + ".quantserve.com/aquant.js?a=p-kGNZ2CXTUFYyw";
#       elem.async = true;
#       elem.type = "text/javascript";
#       var scpt = document.getElementsByTagName('script')[0];
#       scpt.parentNode.insertBefore(elem,scpt);
#       }());
#
#
#       (function(){
#       var label;
#       if(typeof propVar3=='undefined')
#       propVar3 = "";
#       if(typeof propVar15=='undefined')
#       propVar15 = "";
#       if(typeof propVar=='undefined')
#       propVar = "";
#       label = 'Author.'+propVar3+',Category.'+propVar15+'.'+propVar;
#       ezt.push({qacct: 'p-kGNZ2CXTUFYyw',
#       uid: '',
#       labels:label
#       });
#       }());
#   </script>
#   <noscript>
#    <img alt="Quantcast" border="0" height="1" src="//pixel.quantserve.com/pixel/p-kGNZ2CXTUFYyw.gif" style="display: none;" width="1"/>
#   </noscript>
#   <!-- End Quantcast Tag -->
#   <!--********************************* END includes/global-references.inc **************************-->
#   <!-- START page level style/script -->
#   <script type="text/javascript">
#    var mobileModule = createMobileModule("mobileMarketsaccess", "https://m.nasdaq.com/markets/most-active.aspx");
# mobileModule.checkFullSiteAccess();
#   </script>
#   <script src="https://code.highcharts.com/highcharts.js" type="text/javascript">
#   </script>
#   <link href="/includes/highcharts-styles.css" rel="Stylesheet" type="text/css"/>
#   <style type="text/css">
#   </style>
#   <script type="text/javascript">
#    //most-active-pie
#         $(function () {
#             var chart;
#
#             $(document).ready(function () {
#                 var getColor = {
#                     'HELD': '#A8A8A8',
#                     'INCREASED': '#6CB33F',
#                     'DECREASED': '#EE3524'
#                 };
#
#                 var SecuritiesAdvanced = parseInt('1,173'.replace(/\,/g, '')),
#                     SecuritiesDeclined = parseInt('1,945'.replace(/\,/g, '')),
#                     SecuritiesUnchanged = parseInt('202'.replace(/\,/g, ''));
#                 // Build the chart
#                 $('#most-active-pie').highcharts({
#                     chart: {
#                         plotBackgroundColor: null,
#                         plotBorderWidth: null,
#                         plotShadow: false,
#                     },
#                     credits: {
#                         enabled: false
#                     },
#                     exporting: {
#                         enabled: false
#                     },
#                     title: {
#                         text: null
#                     },
#                     tooltip: {
#                         headerFormat: '<span>{point.key}</span>:<br />',
#                         pointFormat: '<b>{point.percentage:.2f}%</b>'
#                     },
#                     plotOptions: {
#                         pie: {
#                             allowPointSelect: true,
#                             cursor: 'pointer',
#                             dataLabels: {
#                                 enabled: false
#                             },
#                             showInLegend: true
#                         }
#                     },
#                     legend: {
#                         itemStyle: {
#                             color: '#6E6E6E',
#                             fontWeight: 'normal',
#                             fontSize: '14px',
#                             lineHeight: '30px'
#                         },
#                         enabled: false,
#                         align: 'center',
#                         verticalAlign: 'bottom',
#                         floating: false,
#                         layout: 'vertical',
#                         symbolHeight: 20,
#                         symbolWidth: 20,
#                         symbolPadding: 10,
#                         itemMarginBottom: 10
#                     },
#                     series: [{
#                         type: 'pie',
#                         name: 'Stocks',
#                         data: [{
#                             name: 'Advanced Stocks',
#                             y: SecuritiesAdvanced,
#                             color: getColor['INCREASED']
#                         }, {
#                             name: 'Declined Stocks',
#                             y: SecuritiesDeclined,
#                             color: getColor['DECREASED']
#                         }, {
#                             name: 'Unchanged Stocks',
#                             y: SecuritiesUnchanged,
#                             sliced: true,
#                             selected: true,
#                             color: getColor['HELD']
#                         }
#                         ]
#                     }]
#                 });
#                 Highcharts.setOptions({
#                     chart: {
#                         style: {
#                             fontFamily: 'sans-serif',
#                             color: '#6E6E6E',
#                         }
#                     }
#                 });
#             });
#
#         });
#
#         //activity-stacked
#         $(function () {
#             var getColor = {
#                 'HIGH': '#6CB33F',
#                 'LOW': '#EE3524'
#             };
#             Highcharts.setOptions({
#                 lang: {
#                     thousandsSep: ','
#                 }
#             });
#
#             var chart_activity = new Highcharts.Chart({
#                 chart: {
#                     renderTo: 'activity-column',
#                     type: 'column',
#                 },
#                 title: {
#                     text: null
#                 },
#                 credits: {
#                     enabled: false
#                 },
#                 exporting: {
#                     enabled: false
#                 },
#                 tooltip: {
#                     headerFormat: '<span>{series.name}</span>: ',
#                     pointFormat: '<b>{point.y}</b>'
#                 },
#                 xAxis: {
#                     categories: ['Stocks'],
#                     labels: {
#                         enabled: false
#                     }
#                 },
#                 yAxis: {
#                     //allowDecimals: false,
#                     title: {
#                         text: null
#                     }
#                 },
#                 legend: {
#                     enabled: false
#                 },
#                 plotOptions: {
#                     column: {
#                         pointPadding: .15,
#                         borderWidth: 0,
#                         groupPadding: 0,
#                         stacking: 'normal',
#                         dataLabels: {
#                             enabled: false,
#                             color: (Highcharts.theme && Highcharts.theme.dataLabelsColor) || 'white',
#                             style: {
#                                 textShadow: '0 0 3px black, 0 0 3px black'
#                             }
#                         }
#                     }
#                 },
#
#                 //stack-0
#                 series: [{
#                     name: 'New Highs',
#                     stack: '0',
#                     color: getColor['HIGH']
#                 }, {
#                     name: 'New Lows',
#                     stack: '0',
#                     color: getColor['LOW']
#                 }]
#             });
#             var newHigh = '64'.replace(/\,/g, '');
#             var newLow = '64'.replace(/\,/g, '');
#              if(!isNaN(parseInt(newHigh)))
#                 chart_activity.series[0].setData([parseInt(newHigh)]);
#             if(!isNaN(parseInt(newLow)))
#                 chart_activity.series[1].setData([-Math.abs(newLow)]);
#         });
#
#         //most-active-column
#         $(function () {
# 			var sAdvancedSymbols = [];
# 			var sAdvancedChanges = [];
# 			var sAdvancedChangesR = [];
#
# 			var sDeclinedSymbols = [];
# 			var sDeclinedChanges = [];
# 			var sDeclinedChangesR = [];
#
# 			var seriesA = [],seriesC = 0;
#
#             var getColor = {
#                 'NEW': '#6CB33F',
#                 'SOLD': '#EE3524',
# 				'symbol': '#000000'
#             };
# 			var getSetting = {
#                 'symbolXoffset':10,
#                 'advanceYoffset':0,
# 				'declineYoffset':15,
# 				'fontSize':'16px'
#             };
#
# 			sAdvancedSymbols[0] = "ENDP";
# 			sAdvancedSymbols[1] = "MREO";
# 			sAdvancedSymbols[2] = "BCEL";
# 			sAdvancedSymbols[3] = "VVUS";
# 			sAdvancedSymbols[4] = "OCC";
#
# 			sAdvancedChanges[0] = 20.9803921568627;
# 			sAdvancedChanges[1] = 16.9605633802817;
# 			sAdvancedChanges[2] = 16.3636363636364;
# 			sAdvancedChanges[3] = 14.7058823529412;
# 			sAdvancedChanges[4] = 12.037037037037;
#
# 			sAdvancedChangesR[0] = Math.round(sAdvancedChanges[0]*100)/100;
# 			sAdvancedChangesR[1] = Math.round(sAdvancedChanges[1]*100)/100;
# 			sAdvancedChangesR[2] = Math.round(sAdvancedChanges[2]*100)/100;
# 			sAdvancedChangesR[3] = Math.round(sAdvancedChanges[3]*100)/100;
# 			sAdvancedChangesR[4] = Math.round(sAdvancedChanges[4]*100)/100;
#
# 			sDeclinedSymbols[0] = "SYBX";
# 			sDeclinedSymbols[1] = "SRPT";
# 			sDeclinedSymbols[2] = "ANAB";
# 			sDeclinedSymbols[3] = "HAIN";
# 			sDeclinedSymbols[4] = "KZR";
#
# 			sDeclinedChanges[0] = -28.7784679089027;
# 			sDeclinedChanges[1] = -17.9079045798354;
# 			sDeclinedChanges[2] = -12.5690890481064;
# 			sDeclinedChanges[3] = -12.2374429223744;
# 			sDeclinedChanges[4] = -10.6212424849699;
#
# 			sDeclinedChangesR[0] = Math.round(sDeclinedChanges[0]*100)/100;
# 			sDeclinedChangesR[1] = Math.round(sDeclinedChanges[1]*100)/100;
# 			sDeclinedChangesR[2] = Math.round(sDeclinedChanges[2]*100)/100;
# 			sDeclinedChangesR[3] = Math.round(sDeclinedChanges[3]*100)/100;
# 			sDeclinedChangesR[4] = Math.round(sDeclinedChanges[4]*100)/100;
#
# 			for(var i=0;i<5;i++)
# 				{
# 					seriesA[seriesC] = {
# 	                    name: sAdvancedSymbols[i],
# 	                    data: [{
# 							y: sAdvancedChanges[i],
# 	                        url: '/symbol/'+formatSymbol(sAdvancedSymbols[i])
# 	                    }],
# 	                    stack: i+"",
# 	                    color: getColor['NEW']
# 					};
#
# 					seriesA[seriesC+1] = {
# 	                    name: sDeclinedSymbols[i],
# 	                    data: [{
# 							y: sDeclinedChanges[i],
# 	                        url: '/symbol/'+formatSymbol(sDeclinedSymbols[i])
# 	                    }],
# 	                    stack: i+"",
# 	                    color: getColor['SOLD']
# 					};
# 					seriesC+=2;
# 				}
# 			seriesC = 0;
#
#             $('#most-active-column').highcharts({
#                 chart: {
#                     type: 'column'
#                 },
#                 title: {
#                     text: null
#                 },
#                 credits: {
#                     enabled: false
#                 },
#                 exporting: {
#                     enabled: false
#                 },
#                 xAxis: {
#                     categories: ['0'],
#                     labels: {
#                         enabled: false
#                     }
#                 },
#                 yAxis: {
#                     allowDecimals: true,
#                     title: {
#                         text: null
#                     },
#                     labels: {
#                         format: '{value}%'
#                     }
#                 },
#                 legend: {
#                     enabled: false
#                 },
#                 tooltip: {
#                     valueSuffix: '%',
#                     enabled: false
#                 },
#                 plotOptions: {
#                     series: {
#                         allowPointSelect: false,
#                         cursor: 'pointer',
#                         point: {
#                             events: {
#                                 click: function () {
#                                     location.href = this.options.url;
#                                 }
#                             }
#                         }
#                     },
#                     column: {
#                         pointPadding: .05,
#                         borderWidth: 0,
#                         groupPadding: 0,
#                         stacking: 'normal',
#                         dataLabels: {
#                             enabled: false,
#                             color: (Highcharts.theme && Highcharts.theme.dataLabelsColor) || 'white',
#                             format: '{series.name}: {y:.2f}%'
#                         }
#                     }
#                 },
#                 series: seriesA
#             }, function(chart){
# 				var point, text;
# 				for(var i=0;i<5;i++)
# 				{
# 					point = chart.series[seriesC].data[0],
#              		text = chart.renderer.text(
#                 		sAdvancedSymbols[i] + " " +sAdvancedChangesR[i]+'%',
#                 		point.plotX*(i*0.4) + chart.plotLeft + getSetting["symbolXoffset"],
#                 		point.plotY + chart.plotTop + getSetting["advanceYoffset"]
#              		).attr({
#              		   zIndex: 5
#              		}).css({
#              		   color: getColor['symbol'],
#              		   fontSize: getSetting["fontSize"],
# 						cursor: "pointer"
#             		}).on('click', (function(sym){
# 						return function(){
#             		    	document.location.href = '/symbol/'+sym;
#             			};
# 					})(formatSymbol(sAdvancedSymbols[i]))).add();
#
# 					point = chart.series[seriesC+1].data[0],
#              		text = chart.renderer.text(
#                 		sDeclinedSymbols[i] + " " +sDeclinedChangesR[i]+'%',
#                 		point.plotX*(i*0.4) + chart.plotLeft + getSetting["symbolXoffset"],
#                 		point.plotY + chart.plotTop + getSetting["declineYoffset"]
#              		).attr({
#              		   zIndex: 5
#              		}).css({
#              		   color: getColor['symbol'],
#              		   fontSize: getSetting["fontSize"],
# 						cursor: "pointer"
#             		}).on('click', (function(sym){
# 						return function(){
#             		    	document.location.href = '/symbol/'+sym;
#             			};
# 					})(formatSymbol(sDeclinedSymbols[i]))).add();
#
# 					seriesC+=2;
# 				}
# 		    });
#         });
#
#     //ad refresh
#
#     (function () {
#         //array holding indexes into gSlots array of ads to be refreshed
#         var refreshableIndexes = [];
#         //tracks the number of premake blocks which fail to render an ad
#         //need this because refreshableIndex array values will be used as indexes to gSlots array, where failed blocks won't exist
#         var failIndex = 0;
#
#         function evalBlock(adBlock, index) {
#         if (adBlock.label == "ad") {
#             if (adBlock.site == "btf")
#                 refreshableIndexes.push(index);
#         }
#         if (adBlock.label == "condition") {
#             if (adBlock.expression != "adRotatorRandom" && adBlock.expression != "adRotatorRandomSwitch") {
#                 if (adBlock.expression == true)
#                     evalBlock(adBlock["true"], index);
#                 else if (adBlock.hasOwnProperty("false"))
#                     evalBlock(adBlock["false"], index);
#                 else
#                     failIndex++;//block failed to render an ad
#             }
#             else {
#                 if (adBlock.expression == "adRotatorRandom") {
#                     if (adRotatorRandStore[adBlock.randIndex])
#                         evalBlock(adBlock['true'], index);
#                     else if (adBlock.hasOwnProperty("false"))
#                         evalBlock(adBlock["false"], index);
#                     else
#                         failIndex++;//block failed to render an ad
#                 }
#                 else {//eval the block at the index resulting from the random switch
#                     evalBlock(adBlock[adRotatorRandStore[adBlock.randIndex]], index);
#                 }
#             }
#         }
#     }
#
#         premakeAds.forEach(function (adBlock, index) {
#             evalBlock(adBlock, index - failIndex);
#         });
#
#         googletag.cmd.push(function () {
#             autoAdRefresh(refreshableIndexes, 60000);
#         });
#     })();
#   </script>
#   <!-- END page level style/script -->
#   <script type="text/javascript">
#    var server_time = new Date(1566325103394);
#   </script>
#   <style type="text/css">
#    #container.wrap {background-color:#ffffff}
#   </style>
#  </head>
#  <body id="body">
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K2BQVP7" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!--[if IE 8]> <script src="/includes/respond.js"></script> <![endif]-->
#   <!--[if IE 7]> <script src="/includes/zindex.js"></script> <![endif]-->
#   <!--*************************************** BEGIN includes/global-masthead.inc ****************************************-->
#   <!-- comscore tag -->
#   <!-- Begin comScore Tag -->
#   <script>
#    var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "25698457" });
#   (function() {
#   var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#   s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
#   </script>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=25698457&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <!-- End comScore Tag -->
#   <!-- end comscore tag -->
#   <header data-role="header" id="global_header">
#    <!--// Begin Hot Topics -->
#    <div id="hot_topics">
#     <div>
#      <b>
#       Hot Topics:
#      </b>
#     </div>
#     <a href="/etfs" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:ETFs')">
#      ETFs
#     </a>
#     <span>
#      |
#     </span>
#     <a href="https://stocktracker.nasdaq.com/smart-portfolio/welcome" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:SmartPT')">
#      Smart Portfolio
#     </a>
#     <span>
#      |
#     </span>
#     <a href="/forex/" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:Currencies')">
#      Currencies
#     </a>
#     <span>
#      |
#     </span>
#     <a href="/investing/online-brokers/" onclick="triggerAsyncOmnitureClickEvent('nav:hot-topics:Broker')">
#      Online Broker Center
#     </a>
#    </div>
#    <!--// End Hot Topics -->
#    <nav id="global_nav">
#     <div id="header_wrap">
#      <div class="logo">
#       <a href="/" onclick="triggerAsyncOmnitureClickEvent('nav:links:homepage')" target="_self">
#        <span>
#        </span>
#       </a>
#      </div>
#      <div id="nasdaq_login">
#       <div id="nWelcome">
#       </div>
#       <div id="mainNav-88x31">
#        <script language="javascript" type="text/javascript">
#         makeAd('','88x31','masthead',is_dartZone,'','');
#        </script>
#       </div>
#       <!--// Begin notifier placeholder -->
#       <div class="floatR" id="global_notifier">
#        <div class="ideaMelt" melt-notifier="">
#        </div>
#       </div>
#       <!--// End notifier placeholder -->
#      </div>
#     </div>
#     <div class="clearB">
#     </div>
#     <ul class="js-nav-toggle primary" id="js-nav-toggle">
#      <li id="site-nav-company">
#       <a data-click-event="nav:company:company-hub" href="https://business.nasdaq.com" onclick="triggerAsyncOmnitureClickEvent('nav:company:company-hub')">
#        <span>
#         Our Businesses
#        </span>
#       </a>
#       <div class="global_dropdown">
#        <div>
#         <div class="floatL half">
#          <ul>
#           <li>
#            <a href="https://business.nasdaq.com/tech" onclick="triggerAsyncOmnitureClickEvent('nav:company:tech')">
#             <b>
#              Tech
#             </b>
#            </a>
#            <a href="https://business.nasdaq.com/tech" onclick="triggerAsyncOmnitureClickEvent('nav:company:tech')">
#             Differentiate With
#             <br/>
#             Technology
#            </a>
#           </li>
#           <li>
#            <a href="https://business.nasdaq.com/trade" onclick="triggerAsyncOmnitureClickEvent('nav:company:trade')">
#             <b>
#              Trade
#             </b>
#            </a>
#            <a href="https://business.nasdaq.com/trade" onclick="triggerAsyncOmnitureClickEvent('nav:company:trade')">
#             Trade Multiple
#             <br/>
#             Asset Classes
#            </a>
#           </li>
#           <li>
#            <a href="https://business.nasdaq.com/track" onclick="triggerAsyncOmnitureClickEvent('nav:company:track')">
#             <b>
#              Track
#             </b>
#            </a>
#            <a href="https://business.nasdaq.com/track" onclick="triggerAsyncOmnitureClickEvent('nav:company:track')">
#             Track the Markets
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="displayIB half">
#          <ul>
#           <li>
#            <a href="https://business.nasdaq.com/intel" onclick="triggerAsyncOmnitureClickEvent('nav:company:intel')">
#             <b>
#              Intel
#             </b>
#            </a>
#            <a href="https://business.nasdaq.com/intel" onclick="triggerAsyncOmnitureClickEvent('nav:company:intel')">
#             Leverage Actionable
#             <br/>
#             Intelligence
#            </a>
#           </li>
#           <li>
#            <a href="https://business.nasdaq.com/list" onclick="triggerAsyncOmnitureClickEvent('nav:company:list')">
#             <b>
#              List
#             </b>
#            </a>
#            <a href="https://business.nasdaq.com/list" onclick="triggerAsyncOmnitureClickEvent('nav:company:list')">
#             Access Capital
#            </a>
#            <a href="https://listingcenter.nasdaq.com/" onclick="triggerAsyncOmnitureClickEvent('nav:company:list')">
#             Listing Center
#            </a>
#           </li>
#           <li>
#            <a href="https://business.nasdaq.com/discover" onclick="triggerAsyncOmnitureClickEvent('nav:company:discover')">
#             <b>
#              Discover
#             </b>
#            </a>
#            <a href="https://business.nasdaq.com/discover" onclick="triggerAsyncOmnitureClickEvent('nav:company:discover')">
#             Discover Nasdaq
#            </a>
#            <a href="https://business.nasdaq.com/marketinsite" onclick="triggerAsyncOmnitureClickEvent('nav:company:discover')">
#             Nasdaq Blog
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <!--// Begin includes/main-nav-company-featured.inc -->
#        <div class="table-table featured">
#         <div class="table-row">
#          <div class="table-cell">
#           <a href="https://nasdaq.com/rewritetomorrow" onclick="triggerAsyncOmnitureClickEvent('nav:company:rewritetomorrow')">
#            <img alt="Rewrite Tomorrow featured image" height="80" src="/images/rewritetomorrow80x80-10082018v4.jpg" width="80"/>
#           </a>
#          </div>
#          <div class="table-cell">
#           <a href="https://nasdaq.com/rewritetomorrow" onclick="triggerAsyncOmnitureClickEvent('nav:company:rewritetomorrow')">
#            <b>
#             Rewrite Tomorrow
#            </b>
#           </a>
#           <div class="clearB">
#           </div>
#           <span>
#            Tomorrow is a market of endless possibilities, learn more
#           </span>
#          </div>
#         </div>
#        </div>
#        <!--// End includes/main-nav-company-featured.inc -->
#       </div>
#      </li>
#      <li id="site-nav-quotes">
#       <a data-click-event="nav:quotes:quotes-hub" href="/quotes" onclick="triggerAsyncOmnitureClickEvent('nav:quotes:quotes-hub')">
#        <span>
#         Quotes
#        </span>
#       </a>
#       <div class="global_dropdown">
#        <div>
#         <div class="floatL half">
#          <ul>
#           <li>
#            <a href="/quotes/" onclick="triggerAsyncOmnitureClickEvent('nav:quotes:quotes-hub')">
#             <b>
#              Quotes &amp; Research
#             </b>
#            </a>
#            <a href="/aspx/flashquotes.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:quotes:flash-quotes')">
#             Flash Quotes
#            </a>
#            <a href="/aspx/infoquotes.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:quotes:info-quotes')">
#             InfoQuotes
#            </a>
#            <a href="/quotes/stock-quotes.aspx" onclick="handleNQClick(this,'nav:quotes:summary-quotes')">
#             Summary Quotes
#            </a>
#            <a href="/quotes/real-time.aspx" onclick="handleNQClick(this,'nav:quotes:real-time')">
#             Real-time Quotes
#            </a>
#            <a href="/extended-trading/" onclick="handleNQClick(this,'nav:quotes:extended-trading')">
#             Extended Trading
#            </a>
#            <a href="/options/" onclick="handleNQClick(this,'nav:quotes:options')">
#             Options Trading Center
#            </a>
#            <a href="/quotes/historical-quotes.aspx" onclick="handleNQClick(this,'nav:quotes:historical-quotes')">
#             Historical Quotes
#            </a>
#           </li>
#           <li>
#            <span class="fontS14px">
#             <b>
#              Charts
#             </b>
#            </span>
#            <a href="/quotes/stock-charts.aspx" onclick="handleNQClick(this,'nav:quotes:basic-charts')">
#             Basic Charts
#            </a>
#            <a href="/quotes/interactive-charts.aspx" onclick="handleNQClick(this,'nav:quotes:interactive-charts')">
#             Interactive Charts
#            </a>
#           </li>
#           <li>
#            <span class="fontS14px">
#             <b>
#              Companies
#             </b>
#            </span>
#            <a href="/quotes/company-news.aspx" onclick="handleNQClick(this,'nav:quotes:news')">
#             Company News
#            </a>
#            <a href="/quotes/press-releases.aspx" onclick="handleNQClick(this,'nav:quotes:press-releases')">
#             Press Releases
#            </a>
#            <a href="/screening/company-list.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:quotes:company-list')">
#             Company List
#            </a>
#            <a href="/screening/companies-by-industry.aspx?exchange=NASDAQ" onclick="handleNQClick(this,'nav:quotes:nasdaq')">
#             Nasdaq Companies
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="floatR half">
#          <ul>
#           <li>
#            <span class="fontS14px">
#             <b>
#              Stock Analysis
#             </b>
#            </span>
#            <a href="/quotes/analyst-research.aspx" onclick="handleNQClick(this,'nav:quotes:analyst-research')">
#             Analyst Research
#            </a>
#            <a href="/quotes/stock-guru-analysis.aspx" onclick="handleNQClick(this,'nav:quotes:guru-analysis')">
#             Guru Analysis
#            </a>
#            <a href="/quotes/stock-reports.aspx" onclick="handleNQClick(this,'nav:quotes:stock-reports')">
#             Stock Reports
#            </a>
#            <a href="/quotes/business-competitors.aspx" onclick="handleNQClick(this,'nav:quotes:competitors')">
#             Competitors
#            </a>
#           </li>
#           <li>
#            <span class="fontS14px">
#             <b>
#              Fundamentals
#             </b>
#            </span>
#            <a href="/quotes/company-financials.aspx" onclick="handleNQClick(this,'nav:quotes:financials')">
#             Financials
#            </a>
#            <a href="/quotes/revenue-eps.aspx" onclick="handleNQClick(this,'nav:quotes:revenue-eps')">
#             Revenue/EPS
#            </a>
#            <a href="/quotes/sec-filings.aspx" onclick="handleNQClick(this,'nav:quotes:sec-filings')">
#             SEC Filings
#            </a>
#            <a href="/quotes/short-interest.aspx" onclick="handleNQClick(this,'nav:quotes:short-interest')">
#             Short Interest
#            </a>
#            <a href="/quotes/dividend-history.aspx" onclick="handleNQClick(this,'nav:quotes:dividend-history')">
#             Dividend History
#            </a>
#           </li>
#           <li>
#            <span class="fontS14px">
#             <b>
#              Holdings
#             </b>
#            </span>
#            <a href="/quotes/ownership.aspx" onclick="handleNQClick(this,'nav:quotes:ownership')">
#             Ownership Summary
#            </a>
#            <a href="/quotes/institutional-holdings.aspx" onclick="handleNQClick(this,'nav:quotes:institutional-holdings')">
#             Institutional Holdings
#            </a>
#            <a href="/quotes/insider-trades.aspx" onclick="handleNQClick(this,'nav:quotes:insider-trades')">
#             Insiders Form 4
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="clearB">
#         </div>
#        </div>
#       </div>
#      </li>
#      <li id="site-nav-markets">
#       <a data-click-event="nav:markets:markets-hub" href="/markets/" onclick="triggerAsyncOmnitureClickEvent('nav:markets:markets-hub')">
#        <span>
#         Markets
#        </span>
#       </a>
#       <div class="global_dropdown">
#        <div>
#         <div class="floatL half">
#          <ul>
#           <li>
#            <a href="/extended-trading/" onclick="triggerAsyncOmnitureClickEvent('nav:markets:extended')">
#             <b>
#              Extended Hours
#             </b>
#            </a>
#            <a href="/extended-trading/premarket-mostactive.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:pre-market')">
#             Pre-Market Activity
#            </a>
#            <a href="/extended-trading/afterhours-mostactive.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:after-hours')">
#             After Hours Activity
#            </a>
#           </li>
#           <li>
#            <span class="fontS14px">
#             <b>
#              Stocks
#             </b>
#            </span>
#            <a href="/aspx/mostactive.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:most-active')">
#             Most Active
#            </a>
#            <a href="/markets/unusual-volume.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:unusual-volume')">
#             Unusual Volume
#            </a>
#            <a href="/aspx/52-week-high-low.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:52-week-high-low')">
#             52 Week High/Low
#            </a>
#            <a href="/markets/upcoming-splits.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:upcoming-splits')">
#             Upcoming Splits
#            </a>
#            <a href="/markets/sec-filings-n.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:sec-filings')">
#             New SEC Filings
#            </a>
#            <a href="/markets/ipos" onclick="triggerAsyncOmnitureClickEvent('nav:markets:ipo-summary')">
#             IPO Summary
#            </a>
#            <a href="/earnings/earnings-calendar.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:earnings-calendar')">
#             Earnings Calendar
#            </a>
#            <a href="/dividend-stocks/" onclick="triggerAsyncOmnitureClickEvent('nav:markets:dividend-stocks')">
#             Dividend Stocks
#            </a>
#            <a href="/markets/barchart-sectors.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:sector-analysis')">
#             Sector Analysis
#            </a>
#           </li>
#           <li>
#            <a href="/forex/" onclick="triggerAsyncOmnitureClickEvent('nav:markets:forex')">
#             <b>
#              Forex
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="floatR half">
#          <ul>
#           <li>
#            <a href="/markets/commodities.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:commodities')">
#             <b>
#              Commodities
#             </b>
#            </a>
#            <a href="/markets/gold.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:gold')">
#             Gold
#            </a>
#            <a href="/markets/crude-oil.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:crude-oil')">
#             Oil
#            </a>
#           </li>
#           <li>
#            <span class="fontS14px">
#             <b>
#              Analyst Activity
#             </b>
#            </span>
#            <a href="/earnings/daily-analyst-recommendations.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:upgrades-downgrades')">
#             Upgrades/Downgrades
#            </a>
#            <a href="/earnings/analyst-forecast-change.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:analyst-forecast-change')">
#             Forecast Changes
#            </a>
#            <a class="a-mega" href="/earnings/daily-earnings-surprise.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:daily-earnings-surprise')">
#             Earning Surprises
#            </a>
#           </li>
#           <li>
#            <a href="/markets/indices/" onclick="triggerAsyncOmnitureClickEvent('nav:markets:indices')">
#             <b>
#              Indices
#             </b>
#            </a>
#            <a href="/markets/indices/major-indices.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:market-indices')">
#             Major Stock Indices
#            </a>
#            <a href="/markets/indices/sector-indices.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:sector-indices')">
#             Market Sector Indices
#            </a>
#            <a href="/markets/index-highs" onclick="triggerAsyncOmnitureClickEvent('nav:markets:statistical-milestones')">
#             Statistical Milestones
#            </a>
#           </li>
#           <li>
#            <a href="/markets/global-markets.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:markets:global-markets')">
#             <b>
#              Global Markets
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="clearB">
#         </div>
#        </div>
#       </div>
#      </li>
#      <li id="site-nav-news">
#       <a data-click-event="nav:news:news-hub" href="/news/" onclick="triggerAsyncOmnitureClickEvent('nav:news:news-hub')">
#        <span>
#         News
#        </span>
#       </a>
#       <div class="global_dropdown">
#        <div>
#         <div class="floatL half">
#          <ul>
#           <li>
#            <a href="/quotes/company-news.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:news:company-news')">
#             <b>
#              Company News
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/news/market-headlines.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:news:market-headlines')">
#             <b>
#              Market Headlines
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/topic/marketinsite" onclick="triggerAsyncOmnitureClickEvent('nav:news:marketinsite')">
#             <b>
#              MarketInsite
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="floatR half">
#          <ul>
#           <li>
#            <a href="/markets/us-economic-calendar.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:news:economic-calendar')">
#             <b>
#              Economic Calendar
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/tech/" onclick="triggerAsyncOmnitureClickEvent('nav:news:technology')">
#             <b>
#              Technology News
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/tomorrowscapital/" onclick="triggerAsyncOmnitureClickEvent('nav:news:tomorrowscapital')">
#             <b>
#              Tomorrow's Capital Podcast
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="clearB">
#         </div>
#        </div>
#        <!-- Begin includes/main-navigation-featured-video.inc -->
#        <div class="table-table featured">
#         <div class="table-row">
#          <div class="table-cell">
#           <a href="/article/inverted-what-searches-for-obscure-financial-term-spike-on-google-20190820-00254" onclick="triggerAsyncOmnitureClickEvent('nav:news:featured-article')">
#            <img height="80" src="/images/news/0820news-am2.jpg" width="80"/>
#           </a>
#          </div>
#          <div class="table-cell">
#           <a href="/article/inverted-what-searches-for-obscure-financial-term-spike-on-google-20190820-00254" onclick="triggerAsyncOmnitureClickEvent('nav:news:featured-article')">
#            Inverted What? Searches for Obscure Financial Term Spike on Google
#           </a>
#           <div class="clearB">
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- End includes/main-navigation-featured-video.inc -->
#       </div>
#      </li>
#      <li id="site-nav-investing">
#       <a data-click-event="nav:investing:investing-hub" href="/investing/" onclick="triggerAsyncOmnitureClickEvent('nav:investing:investing-hub')">
#        <span>
#         Investing
#        </span>
#       </a>
#       <div class="global_dropdown">
#        <div>
#         <div class="floatL half">
#          <ul>
#           <li>
#            <a href="/investing/stocks.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:investing:stocks')">
#             <b>
#              Stocks
#             </b>
#            </a>
#            <a href="/investing/how-to-invest.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:investing:investing-basics')">
#             Investing Basics
#            </a>
#            <a href="/investing/online-brokers/" onclick="triggerAsyncOmnitureClickEvent('nav:investing:online-brokers')">
#             Broker Comparison
#            </a>
#            <a href="/investing/glossary/" onclick="triggerAsyncOmnitureClickEvent('nav:investing:glossary')">
#             Glossary
#            </a>
#           </li>
#           <li>
#            <a href="/investing/mutual-funds.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:investing:mutual-funds')">
#             <b>
#              Mutual Funds
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/etfs" onclick="triggerAsyncOmnitureClickEvent('nav:investing:etfs')">
#             <b>
#              ETFs
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/options/" onclick="triggerAsyncOmnitureClickEvent('nav:investing:options')">
#             <b>
#              Options
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="floatR half">
#          <ul>
#           <li>
#            <a href="/investing/tools.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:investing:tools')">
#             <b>
#              Investing Tools
#             </b>
#            </a>
#            <a href="/reference/stock-screener.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:investing:stock-screener')">
#             Stock Screener
#            </a>
#            <a href="/investing/guru/guru-stock-screener.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:investing:guru-screener')">
#             Guru Screener
#            </a>
#           </li>
#           <li>
#            <a href="/advisor/" onclick="triggerAsyncOmnitureClickEvent('nav:investing:advisor')">
#             <b>
#              Financial Advisor
#              <br/>
#              Center
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/investing/bonds.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:investing:bonds')">
#             <b>
#              Bonds
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="clearB">
#         </div>
#        </div>
#        <!--// Begin includes/main-nav-investing-feature.inc -->
#        <div class="table-table featured">
#         <div class="table-row">
#          <div class="table-cell">
#           <a href="/article/how-data-is-making-the-us-stock-market-open-for-all-investors-cm998274" onclick="triggerAsyncOmnitureClickEvent('nav:investing:the-anatomy-of-the-trade')">
#            <img border="0" height="80" src="/images/anatomy-of-a-trade80x80.jpg" width="80"/>
#           </a>
#          </div>
#          <div class="table-cell">
#           <a href="/article/how-data-is-making-the-us-stock-market-open-for-all-investors-cm998274" onclick="triggerAsyncOmnitureClickEvent('nav:investing:the-anatomy-of-the-trade')">
#            <b>
#             The Anatomy of a Trade
#            </b>
#           </a>
#           <div class="clearB">
#           </div>
#           <span>
#            How data is making the U.S. stock market more open for all
#           </span>
#          </div>
#         </div>
#        </div>
#        <!--// End includes/main-nav-investing-feature.inc -->
#       </div>
#      </li>
#      <li id="site-nav-pf">
#       <a data-click-event="nav:personal-finance:pf-hub" href="/personal-finance/" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:pf-hub')">
#        <span>
#         Personal Finance
#        </span>
#       </a>
#       <div class="global_dropdown">
#        <div>
#         <div class="floatL half">
#          <ul>
#           <li>
#            <a href="/personal-finance/retirement.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:retirement')">
#             <b>
#              Retirement
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/personal-finance/real-estate.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:real-estate')">
#             <b>
#              Real Estate
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/personal-finance/banking.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:banking')">
#             <b>
#              Banking
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/personal-finance/insurance.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:insurance')">
#             <b>
#              Insurance
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="floatR half">
#          <ul>
#           <li>
#            <a href="/personal-finance/saving-money/" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:saving-money')">
#             <b>
#              Saving Money
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/personal-finance/taxes.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:taxes')">
#             <b>
#              Taxes
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/personal-finance/investments.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:investments')">
#             <b>
#              Investments
#             </b>
#            </a>
#           </li>
#           <li>
#            <a href="/personal-finance/small-business.aspx" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:small-business')">
#             <b>
#              Small Business
#             </b>
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="clearB">
#         </div>
#        </div>
#        <!--// Begin includes/main-navigation-featured-article.inc -->
#        <div class="table-table featured">
#         <div class="table-row">
#          <div class="table-cell">
#           <a href="/article/5-credit-card-perks-and-freebies-you-may-not-know-you-have-cm1200290" onclick="triggerAsyncOmnitureClickEvent('nav:personal-finance:featured-article')">
# ...
#          Glossary
#         </a>
#         <span>
#          /
#         </span>
#        </li>
#        <li>
#         <a href="/feedback/" title="Feedback">
#          Feedback
#         </a>
#        </li>
#       </ul>
#      </nav>
#     </div>
#    </div>
#   </footer>
#   <!--// end footer -->
#   <!-- begin lightbox backdrop -->
#   <table class="backdrop" id="backdrop">
#    <tr>
#     <td>
#      <!-- begin lightboxness -->
#      <div class="lightbox edit-stocks" id="edit-stocks">
#       <!-- close button-->
#       <span class="close">
#        CLOSE
#        <span class="x">
#         X
#        </span>
#       </span>
#       <div class="floatL">
#        <h2>
#         <center>
#          Edit Favorites
#         </center>
#        </h2>
#        <!-- text -->
#        <p>
#         Enter up to 25 symbols separated by commas or spaces in the text box below. These symbols will be available during your session for use on applicable pages.
#        </p>
#        <!-- input box -->
#        <div class="floatL">
#         <textarea class="fontS14px" cols="35" id="myListInput" name="myListInput" onkeypress="if(event.keyCode ==13){nasdaqIndexRow.myListGo()}else if(event.keyCode == 27){$('.close').click();}" rows="3"></textarea>
#        </div>
#        <!-- right side controls -->
#        <div class="floatL marginL10px">
#         <a class="lightgreen-button marginB5px TalignC" href="javascript:void(0)" onclick="nasdaqIndexRow.myListGo();">
#          Update
#         </a>
#         <br/>
#         <a class="red-button" href="javascript:void(0)" onclick="nasdaqIndexRow.clearMyList();">
#          Clear List
#         </a>
#        </div>
#       </div>
#      </div>
#      <!-- end lightboxness -->
#      <!-- begin lightboxness -->
#      <div class="lightbox stock-searches" id="stock-searches">
#       <!-- close button-->
#       <span class="close">
#        CLOSE
#        <span class="x">
#         X
#        </span>
#       </span>
#       <h2>
#        Customize your NASDAQ.com experience
#       </h2>
#       <b>
#        Background Color Selector
#       </b>
#       <br/>
#       <span>
#        Select the background color of your choice:
#       </span>
#       <div class="clearB">
#       </div>
#       <div id="BgSelector">
#        <div>
#         <div class="BgSelector-1">
#          <div class="floatL">
#           <input name="themepreference" onclick="updateSiteTheme(this.value)" type="radio" value="blackg"/>
#           Black
#          </div>
#          <div class="BgSelector-color">
#          </div>
#         </div>
#         <div class="clearB">
#         </div>
#         <div class="BgSelector-2">
#          <div class="floatL">
#           <input name="themepreference" onclick="updateSiteTheme(this.value)" type="radio" value="slateg"/>
#           Slate Gray
#          </div>
#          <div class="BgSelector-color">
#          </div>
#         </div>
#        </div>
#        <div>
#         <div class="BgSelector-3">
#          <div class="floatL">
#           <input name="themepreference" onclick="updateSiteTheme(this.value)" type="radio" value="lightg"/>
#           Light Gray
#          </div>
#          <div class="BgSelector-color">
#          </div>
#         </div>
#         <div class="clearB">
#         </div>
#         <div class="BgSelector-4">
#          <div class="floatL">
#           <input name="themepreference" onclick="updateSiteTheme(this.value)" type="radio" value="grayb"/>
#           Gray Blue
#          </div>
#          <div class="BgSelector-color">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="clearB">
#       </div>
#       <hr/>
#       <br/>
#       <b>
#        Quote Search
#       </b>
#       <br/>
#       <span>
#        Select a default target page for your quote search:
#       </span>
#       <div id="QuoteSetting">
#        <div>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="realtime"/>
#         Real-Time
#         <br/>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="afthours"/>
#         After Hours
#         <br/>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="premkt"/>
#         Pre-Market
#         <br/>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="compnews"/>
#         News
#        </div>
#        <div>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="flash"/>
#         Flash Quote
#         <br/>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="summary"/>
#         Summary Quote
#         <br/>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="dyncharts"/>
#         Interactive Charts
#         <br/>
#         <input name="quotepreference" onclick="Nasdaq_Quotesearch.confirmUserPref(this.value)" type="radio" value="default"/>
#         Default Setting
#         <br/>
#        </div>
#       </div>
#       <div class="clearB">
#       </div>
#       <span>
#        Please note that once you make your selection, it will apply to all future visits to NASDAQ.com.
# 					If, at any time, you are interested in reverting to our default settings, please select Default Setting above.
#        <br/>
#        <br/>
#        If you have any questions or encounter any issues in changing your default settings, please email
#        <a href="mailto:isfeedback@nasdaq.com?Subject=Default%20Settings%20Inquiry">
#         isfeedback@nasdaq.com
#        </a>
#        .
#       </span>
#      </div>
#      <!-- end lightboxness -->
#      <!-- begin lightboxness -->
#      <div class="lightbox" id="confirm">
#       <!-- close button-->
#       <span class="close">
#        CLOSE
#        <span class="x">
#         X
#        </span>
#       </span>
#       <h4>
#        Please confirm your selection:
#       </h4>
#       <p>
#        You have selected to change your default setting for the Quote Search. This will now be your default target page;
# 					unless you change your configuration again, or you delete your
# 					cookies.
#        <b>
#         Are you sure you want to change your settings?
#        </b>
#       </p>
#       <div>
#        <button class="floatL" onclick="Nasdaq_Quotesearch.confirmHandler('defaultQuote', true)">
#         YES
#        </button>
#        <button class="floatR" onclick="Nasdaq_Quotesearch.confirmHandler('defaultQuote', false)">
#         NO
#        </button>
#       </div>
#      </div>
#      <!-- end lightboxness -->
#     </td>
#    </tr>
#   </table>
#   <!-- end lightbox backdrop -->
#   <table class="backdrop" id="globalCustomModal">
#    <tr>
#     <td>
#      <!-- begin lightboxness -->
#      <div class="lightbox" id="adBlockMsg">
#       <!-- close button-->
#       <span class="close" onclick="close_global_modal()">
#        CLOSE
#        <span class="x">
#         X
#        </span>
#       </span>
#       <!-- <h2><center>We have a favor to ask</center></h2> -->
#       <!-- text -->
#       <p id="adBlockMsgText">
#        Please disable your ad blocker (or
#        <a href="/help/adblock-instructions.aspx">
#         update your settings
#        </a>
#        to ensure that javascript and cookies are enabled), so that we can continue to provide you with the first-rate market news and data you've come to expect from us.
#       </p>
#      </div>
#      <!-- end lightboxness -->
#      <!-- begin lightboxness -->
#      <div class="lightbox" id="interstitialAdContainer" style="width:705px;height:575px">
#       <!-- close button-->
#       <span class="close" onclick="close_global_modal()">
#        CLOSE
#        <span class="x">
#         X
#        </span>
#       </span>
#       <!-- <h2><center>Sponsor Message</center></h2> -->
#       <!-- text -->
#       <p id="interstitialContainer">
#       </p>
#      </div>
#      <!-- end lightboxness -->
#     </td>
#    </tr>
#   </table>
#   <!-- Omniture code -->
#   <!--********************BEGIN  ../includes/omniture.inc***********************-->
#   <!-- SiteCatalyst code version: H.1.
# Copyright 1997-2005 Omniture, Inc. More info available at https://www.omniture.com -->
#   <script language="JavaScript" src="/includes/s_code-072016v1.js?v=03012016" type="text/javascript">
#   </script>
#   <script language="JavaScript" type="text/javascript">
#    <!--
# if(navigator.appVersion.indexOf('MSIE')>=0)document.write(unescape('%3C')+'\!-'+'-')
# //-->
#   </script>
#   <noscript>
#    <img alt="" border="0" height="1" src="https://nasdaq.122.2O7.net/b/ss/nasdaqprod/1/H.1--NS/0" width="1"/>
#   </noscript>
#   <!--/DO NOT REMOVE/-->
#   <!-- End SiteCatalyst code version: H.1. -->
#   <!-- setSectionName() moved to js file: masthead_default.js -->
#   <!--*********************End  ../includes/omniture.inc*******************************-->
#   <script type="text/javascript">
#    //<![CDATA[
# setSectionName(propVar);
# //]]>
#   </script>
#   <!-- Begin BlueKai Tag -->
#   <iframe frameborder="0" height="0" name="__bkframe" src="about:blank" style="display:none;position:absolute;clip:rect(0px 0px 0px 0px)" width="0">
#   </iframe>
#   <script src="https://tags.bkrtx.com/js/bk-coretag.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    bk_addPageCtx('is_dartSite', (typeof(is_dartSite)!=='undefined')?is_dartSite:'');
# bk_addPageCtx('is_dartZone', (typeof(is_dartZone)!=='undefined')?is_dartZone:'');
# bk_addPageCtx('propVar', (typeof(propVar)!=='undefined')?propVar:'');
# bk_addPageCtx('propVar15', (typeof(propVar15)!=='undefined')?propVar15:'');
# bk_addPageCtx('SymbolType', (typeof(SymbolType)!=='undefined')?SymbolType:'');
# bk_addPageCtx('StockIndustry', (typeof(StockIndustry)!=='undefined')?StockIndustry:'');
# bk_addPageCtx('ArticlePrimaryCategory', (typeof(ArticlePrimaryCategory)!=='undefined')?ArticlePrimaryCategory:'');
#
# bk_doJSTag(31843, 1);
#   </script>
#   <!-- End BlueKai Tag -->
#   <!-- begin Enerprise Florida survey -->
#   <script>
#    /*
# (function(){
# if(document.referrer=="https://www"+host_Extension+".nasdaq.com/markets/ipos/"
# 	&& document.location.href!="https://www"+host_Extension+".nasdaq.com/markets/ipos/"
# 	&& get_cookie_value("EnterpriseFloridaSurvey")==false)
# {
# 	set_cookie_value("EnterpriseFloridaSurvey","true",3);
# 	(function(t,e,s,n){var o,c,a;t.SMCX=t.SMCX||[],e.getElementById(n)||(o=e.getElementsByTagName(s),c=o[o.length-1],a=e.createElement(s),a.type="text/javascript",a.async=!0,a.id=n,a.src=["https:"===location.protocol?"https://":"https://","widget.surveymonkey.com/collect/website/js/DrqdalJhvDd5ACgCO0mDpO1m7_2FEv_2BICPaYzBfwyQJ8_2BsY6t3mPJl0hh2FGypTiFu.js"].join(""),c.parentNode.insertBefore(a,c))})(window,document,"script","smcx-sdk");
# }
# else if(document.location.href=="https://www"+host_Extension+".nasdaq.com/markets/gold.aspx"
# 	&& get_cookie_value("EnterpriseFloridaSurvey")==false)
#   {
#   set_cookie_value("EnterpriseFloridaSurvey","true",7);
#   (function(e,t,n,o){var s,c,i;e.SMCX=e.SMCX||[],t.getElementById(o)||(s=t.getElementsByTagName(n),c=s[s.length-1],i=t.createElement(n),i.type="text/javascript",i.async=!0,i.id=o,i.src=["https:"===location.protocol?"https://":"https://","widget.surveymonkey.com/collect/website/js/zlERY9yXVqREVYHr6ZdqhDNMqk2NLii_2Fefbn4hZPEGkz2TEDYuhOlBtXpQe_2FgiXz.js"].join(""),c.parentNode.insertBefore(i,c))})(window,document,"script","smcx-sdk");
#   }
#   })();
#   */
#
#   //deferred actions
#
#   //deferred actions
#   $(window).on('load', function () {
#   addScript("/includes/nasdaqdeferred.min-04242018v1.js", true, "deferredActions()");
#   });
#   </script>
#   <!-- end Enterprise Florida survey -->
#   <!-- end includes/fixedFooter.inc-->
#   <!-- START page bottom script -->
#   <script type="text/javascript">
#    $(document).ready(function () {
#         setTimeout(function () {
#             initStickyContent();
#         }, 5000);
#     });
#
#     function initStickyContent() {
#         var menuHeight = 85; //masthead height; padding between sticky content and top of the screen
#         var bottomElementSelector = '#footerAd';//bottom boundary element which sticky content won't move past vertically
#         var footerOffset = 0; //padding between sticky content and bottom boundary element
#         var content1Selector = '#sticky-container1';//initial sticky element
#         var content1Height = 411;//height of initial sticky element
#
#         function initStickyContent1() {
#             var stickyContainer = $(content1Selector);
#             if (stickyContainer.length == 0) return;
#             var stickyTop = stickyContainer.offset().top - menuHeight;
#             var maxBottom = $(bottomElementSelector).offset().top - footerOffset;
#             //define scroll distance, bottom point is based on scroll distance
#             var bottom = $(bottomElementSelector).offset().top - footerOffset - content1Height - menuHeight - 600;
#             //if scroll distance goes into footer, readjust
#             if (bottom > maxBottom) bottom = maxBottom;
#             var currentlyStickied = false;
#             var disableSticky = false;
#             var distance = bottom - stickyTop - content1Height - menuHeight;
#             $(window).scroll(function () {
#                 var windowTop;
#                 if (!disableSticky) {
#                     windowTop = $(window).scrollTop();
#                     if (stickyTop < windowTop) {
#                         if (windowTop < bottom) {
#                             if (!currentlyStickied) {
#                                 //scroll position is past sticky point but above bottom point and content is currently non-sticky
#                                 //go from non-sticky to sticky
#                                 stickyContainer.css({ position: 'fixed', top: menuHeight + "px" });
#                                 currentlyStickied = true;
#                             }
#                         }
#                         else {
#                             if (currentlyStickied) {
#                                 //scroll position is past sticky point and past bottom point and content is currently sticky
#                                 //go from sticky to original position and disable future stickiness
#                                 stickyContainer.css({ position: 'fixed', top: (menuHeight - 860) + "px" });
#                                 currentlyStickied = false;
#                             }
#                         }
#                     }
#                     else {
#                         if (currentlyStickied) {
#                             //scroll position is above sticky point but content is currently sticky
#                             //go from sticky to original position
#                             stickyContainer.css('position', 'static');
#                             currentlyStickied = false;
#                         }
#                     }
#                 }
#             });
#         }
#
#         initStickyContent1();
#     }
#   </script>
#   <script type="application/ld+json">
#    {
#         "@context": "https://schema.org",
#         "@type": "WebPage",
#         "mainEntity":{
#             "@type": "WebPage",
#             "@id": "/markets/most-active.aspx"
#         },
#         "breadcrumb":{
#         "@type": "BreadcrumbList",
#         "itemListElement":
#         [
#             {
#                 "@type": "ListItem",
#                 "position": 1,
#                 "item":
#                 {
#                     "@type": "WebPage",
#                     "@id": "/",
#                     "name": "Home"
#                 }
#             },
#             {
#                 "@type": "ListItem",
#                 "position": 2,
#                 "item":
#                 {
#                     "@type": "WebPage",
#                     "@id": "/markets/",
#                     "name": "Market Activity"
#                 }
#             },
#             {
#                 "@type": "ListItem",
#                 "position": 3,
#                 "item":
#                 {
#                     "@type": "WebPage",
#                     "@id": "/markets/most-active.aspx",
#                     "name": "Most Active Stocks"
#                 }
#             }
#         ]
#     }
#     }
#   </script>
#   <!-- END page bottom script -->
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>Most Active Stocks - Most Active Share Volume</title>

# %%
soup.title.string
# Out:
# 'Most Active Stocks - Most Active Share Volume'

# %%
table=soup.find_all('div', attrs='genTable')
all_rows=table[1].find_all('tr')

# %%
# Generate lists
symbol=[]

name=[]

last_sale=[]

change_net=[]

share_volume=[]

 
for row in all_rows:

    cols=row.find_all('td')

    if(len(cols)):
        symbol.append(cols[0].text)
        
        name.append(cols[1].text)

        last_sale.append(cols[3].text)

        change_net.append(cols[4].text)

        share_volume.append(cols[5].text)

# %%
symbol
# Out:
# ['\nENDP\n\n',
#  '\nMREO\n\n',
#  '\nBCEL\n\n',
#  '\nVVUS\n\n',
#  '\nOCC\n\n',
#  '\nJFIN\n\n',
#  '\nVNET\n\n',
#  '\nJFU\n\n',
#  '\nMNLO\n\n',
#  '\nPHAS\n\n',
#  '\nACOR\n\n',
#  '\nCIH\n\n',
#  '\nEVER\n\n',
#  '\nEVLO\n\n',
#  '\nTBIO\n\n',
#  '\nNIU\n\n',
#  '\nLOVE\n\n',
#  '\nGMDA\n\n',
#  '\nNICK\n\n',
#  '\nCHMA\n\n']

# %%
symbol = [x.replace('\n', '') for x in symbol]
symbol
# Out:
# ['ENDP',
#  'MREO',
#  'BCEL',
#  'VVUS',
#  'OCC',
#  'JFIN',
#  'VNET',
#  'JFU',
#  'MNLO',
#  'PHAS',
#  'ACOR',
#  'CIH',
#  'EVER',
#  'EVLO',
#  'TBIO',
#  'NIU',
#  'LOVE',
#  'GMDA',
#  'NICK',
#  'CHMA']

# %%
name
# Out:
# ['Endo International plc',
#  'Mereo BioPharma Group plc',
#  'Atreca, Inc.',
#  'VIVUS, Inc.',
#  'Optical Cable Corporation',
#  'Jiayin Group Inc.',
#  '21Vianet Group, Inc.',
#  '9F Inc.',
#  'Menlo Therapeutics Inc.',
#  'PhaseBio Pharmaceuticals, Inc.',
#  'Acorda Therapeutics, Inc.',
#  'China Index Holdings Limited',
#  'EverQuote, Inc.',
#  'Evelo Biosciences, Inc.',
#  'Translate Bio, Inc.',
#  'Niu Technologies',
#  'The Lovesac Company',
#  'Gamida Cell Ltd.',
#  'Nicholas Financial, Inc.',
#  'Chiasma, Inc.']

# %%
last_sale
# Out:
# ['$ 3.085 ',
#  '$ 4.1521 ',
#  '$ 20.48 ',
#  '$ 3.90 ',
#  '$ 3.9325 ',
#  '$ 12.70 ',
#  '$ 7.80 ',
#  '$ 10.63 ',
#  '$ 4.14 ',
#  '$ 8.15 ',
#  '$ 3.1848 ',
#  '$ 2.38 ',
#  '$ 23.90 ',
#  '$ 6.88 ',
#  '$ 8.69 ',
#  '$ 8.22 ',
#  '$ 18.9675 ',
#  '$ 3.1932 ',
#  '$ 9.30 ',
#  '$ 5.39 ']

# %%
change_net
# Out:
# ['0.535\xa0▲\xa020.98% ',
#  '0.6021\xa0▲\xa016.96% ',
#  '2.88\xa0▲\xa016.36% ',
#  '0.50\xa0▲\xa014.71% ',
#  '0.4225\xa0▲\xa012.04% ',
#  '1.29\xa0▲\xa011.31% ',
#  '0.78\xa0▲\xa011.11% ',
#  '0.91\xa0▲\xa09.36% ',
#  '0.35\xa0▲\xa09.23% ',
#  '0.67\xa0▲\xa08.96% ',
#  '0.2548\xa0▲\xa08.70% ',
#  '0.1799\xa0▲\xa08.18% ',
#  '1.78\xa0▲\xa08.05% ',
#  '0.49\xa0▲\xa07.67% ',
#  '0.55\xa0▲\xa06.76% ',
#  '0.52\xa0▲\xa06.75% ',
#  '1.1875\xa0▲\xa06.68% ',
#  '0.1932\xa0▲\xa06.44% ',
#  '0.55\xa0▲\xa06.29% ',
#  '0.31\xa0▲\xa06.10% ']

# %%
share_volume
# Out:
# ['15,305,100 ',
#  '69,523 ',
#  '105,907 ',
#  '2,729,029 ',
#  '5,551 ',
#  '13,584 ',
#  '443,998 ',
#  '196,175 ',
#  '40,526 ',
#  '56,029 ',
#  '1,264,480 ',
#  '37,901 ',
#  '523,374 ',
#  '23,272 ',
#  '102,099 ',
#  '217,151 ',
#  '130,352 ',
#  '21,665 ',
#  '16,874 ',
#  '189,200 ']

# %%
import pandas as pd

# dictionary of lists  
dict = {'Symbol': symbol, 'Name': name, 'Last_sale': last_sale, 'Change_net': change_net, 
        'Share_volume': share_volume}  

# Save as dataframe
df = pd.DataFrame(dict) 
    
df
# Out:
#    Symbol                            Name   Last_sale        Change_net  \
# 0    ENDP          Endo International plc    $ 3.085    0.535 ▲ 20.98%
# 1    MREO       Mereo BioPharma Group plc   $ 4.1521   0.6021 ▲ 16.96%
# 2    BCEL                    Atreca, Inc.    $ 20.48     2.88 ▲ 16.36%
# 3    VVUS                     VIVUS, Inc.     $ 3.90     0.50 ▲ 14.71%
# 4     OCC       Optical Cable Corporation   $ 3.9325   0.4225 ▲ 12.04%
# 5    JFIN               Jiayin Group Inc.    $ 12.70     1.29 ▲ 11.31%
# 6    VNET            21Vianet Group, Inc.     $ 7.80     0.78 ▲ 11.11%
# 7     JFU                         9F Inc.    $ 10.63      0.91 ▲ 9.36%
# 8    MNLO         Menlo Therapeutics Inc.     $ 4.14      0.35 ▲ 9.23%
# 9    PHAS  PhaseBio Pharmaceuticals, Inc.     $ 8.15      0.67 ▲ 8.96%
# 10   ACOR       Acorda Therapeutics, Inc.   $ 3.1848    0.2548 ▲ 8.70%
# 11    CIH    China Index Holdings Limited     $ 2.38    0.1799 ▲ 8.18%
# 12   EVER                 EverQuote, Inc.    $ 23.90      1.78 ▲ 8.05%
# 13   EVLO         Evelo Biosciences, Inc.     $ 6.88      0.49 ▲ 7.67%
# 14   TBIO             Translate Bio, Inc.     $ 8.69      0.55 ▲ 6.76%
# 15    NIU                Niu Technologies     $ 8.22      0.52 ▲ 6.75%
# 16   LOVE             The Lovesac Company  $ 18.9675    1.1875 ▲ 6.68%
# 17   GMDA                Gamida Cell Ltd.   $ 3.1932    0.1932 ▲ 6.44%
# 18   NICK        Nicholas Financial, Inc.     $ 9.30      0.55 ▲ 6.29%
# 19   CHMA                   Chiasma, Inc.     $ 5.39      0.31 ▲ 6.10%
#
#    Share_volume
# 0   15,305,100
# 1       69,523
# 2      105,907
# 3    2,729,029
# 4        5,551
# 5       13,584
# 6      443,998
# 7      196,175
# 8       40,526
# 9       56,029
# 10   1,264,480
# 11      37,901
# 12     523,374
# 13      23,272
# 14     102,099
# 15     217,151
# 16     130,352
# 17      21,665
# 18      16,874
# 19     189,200
